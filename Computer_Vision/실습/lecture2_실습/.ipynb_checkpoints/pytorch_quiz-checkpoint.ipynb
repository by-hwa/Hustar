# %% [markdown]
# ### Pytorch Quiz
# - CNN을 활용한 모델을 만들어서 정확도 95% 이상의 Classifier를 만드세요
# - 코드 수정 가능

# %%
from matplotlib import pyplot as plt
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader

# %% [markdown]
# #### Dataset download

# %%
train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
dataloader_train = DataLoader(train_data, 
                              batch_size=16, 
                              shuffle=True)

test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)
dataloader_test = DataLoader(test_data, 
                              batch_size=16, 
                              shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data\MNIST\raw\train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data\MNIST\raw\train-images-idx3-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data\MNIST\raw\train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data\MNIST\raw\train-labels-idx1-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data\MNIST\raw\t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data\MNIST\raw\t10k-images-idx3-ubyte.gz to data\MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data\MNIST\raw\t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data\MNIST\raw\t10k-labels-idx1-ubyte.gz to data\MNIST\raw

# %% [markdown]
# #### Check images

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img, label = train_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# #### CNN
# ##### structure
# - Convolution 1 : channels 16, kernel size 5, stride 1, padding 2 (output resolution?)
# - ReLU
# - MaxPool : kernel_size 2, stride 2
# - Convlution 2 : channels 32, kernel size 5, stride 1, padding 2 (output resolution?)
# - Linear : output channels 10
#
# ##### https://pytorch.org/docs/1.12/nn.html

# %%
class CNN(nn.Module):
    def __init__(self):
        ## TODO ##
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels = 1,
                              out_channels = 16,
                              kernel_size = 5,
                              stride = 2,
                              padding = 2)
        self.relu = nn.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size = 2,
                                   stride = 2)
        self.conv2 = nn.Conv2d(in_channels = 16,
                              out_channels = 32,
                              kernel_size = 5,
                              stride = 2,
                              padding = 2)
        self.linear = nn.Linear(in_features = 512,
                               out_features = 10)
    def forward(self, x):
        ## TODO ##
#         print(x.shape)
        x = self.conv1(x)
#         print(x.shape)
        x = self.relu(x)
#         print(x.shape)
        x = self.maxpool(x)
#         print(x.shape)
        x = self.conv2(x)
#         print(x.shape)
        x = x.view(x.shape[0], -1)
#         print(x.shape)
        x = self.linear(x)
#         print(x.shape)
        return x

x = torch.randn(15,1,28,28)
cnn = CNN()
cnn(x)
# Out:
# tensor([[-0.0217,  0.0724,  0.1185, -0.1082,  0.0717, -0.0106,  0.1896, -0.1080,
#           0.0670,  0.0297],
#         [-0.0132,  0.1911,  0.1483, -0.1039,  0.3434, -0.0841,  0.3470, -0.1648,
#          -0.0237,  0.0050],
#         [ 0.1362,  0.0712,  0.1535, -0.0934,  0.2257, -0.0673,  0.2775, -0.1237,
#          -0.0230, -0.0221],
#         [-0.0494,  0.2453,  0.0296, -0.2158,  0.0806,  0.0104,  0.3213,  0.0073,
#          -0.0501, -0.0497],
#         [-0.0571,  0.1281, -0.0093, -0.1334,  0.3418,  0.0484,  0.3503, -0.1863,
#          -0.0423,  0.0021],
#         [-0.0866, -0.0305,  0.1067, -0.2181,  0.1167, -0.0160,  0.4148, -0.1306,
#          -0.0257, -0.1718],
#         [-0.0583,  0.1621,  0.0702, -0.2784,  0.2063, -0.0383,  0.4048, -0.0191,
#          -0.0057,  0.0767],
#         [ 0.0096,  0.2868,  0.1326, -0.3137,  0.2182, -0.0410,  0.3061, -0.0870,
#           0.0005, -0.0203],
#         [ 0.1575,  0.0661,  0.1534, -0.1576,  0.1499, -0.0470,  0.3567, -0.1477,
#          -0.1036, -0.0323],
#         [ 0.2128,  0.1186, -0.0214, -0.3226,  0.1101, -0.0989,  0.2321, -0.0146,
#           0.0886, -0.0127],
#         [-0.0668,  0.2282, -0.1237, -0.3315,  0.1980,  0.0247,  0.2492, -0.0623,
#          -0.1483,  0.0105],
#         [ 0.1156,  0.2401,  0.1048, -0.2438,  0.2750, -0.0240,  0.4583, -0.0699,
#           0.0253,  0.0031],
#         [ 0.1285,  0.1766,  0.0417, -0.2080,  0.1228, -0.0241,  0.3793, -0.0658,
#           0.0591, -0.1257],
#         [-0.0594,  0.2058,  0.1040, -0.0922,  0.2104, -0.0015,  0.2289,  0.0644,
#          -0.0668,  0.0974],
#         [ 0.0071,  0.0846, -0.1679, -0.2903,  0.2681, -0.0724,  0.3081, -0.1250,
#          -0.0981,  0.0653]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# #### Train

# %%
cnn = CNN()
loss_func = nn.CrossEntropyLoss()   
optimizer = optim.Adam(cnn.parameters(), lr = 0.01)

# %%
# Train the model
num_epochs = 5

for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(dataloader_train):
        output = cnn(images)[0]               
        loss = loss_func(output, labels)

        # clear gradients for this training step   
        optimizer.zero_grad()           

        # backpropagation, compute gradients 
        loss.backward()    
        # apply gradients             
        optimizer.step()                

        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}], Loss: {:.4f}' 
                   .format(epoch + 1, num_epochs, i + 1, loss.item()))
# Out:
# C:\Users\owner\Miniconda3\envs\cv_course\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Epoch [1/5], Step [100], Loss: 0.1000
# Epoch [1/5], Step [200], Loss: 0.2912
# Epoch [1/5], Step [300], Loss: 0.0360
# Epoch [1/5], Step [400], Loss: 0.3647
# Epoch [1/5], Step [500], Loss: 0.0234
# Epoch [1/5], Step [600], Loss: 0.2077
# Epoch [1/5], Step [700], Loss: 0.1163
# Epoch [1/5], Step [800], Loss: 0.1942
# Epoch [1/5], Step [900], Loss: 0.2125
# Epoch [1/5], Step [1000], Loss: 0.1928
# Epoch [1/5], Step [1100], Loss: 0.0098
# Epoch [1/5], Step [1200], Loss: 0.3520
# Epoch [1/5], Step [1300], Loss: 0.1294
# Epoch [1/5], Step [1400], Loss: 0.1584
# Epoch [1/5], Step [1500], Loss: 0.3537
# Epoch [1/5], Step [1600], Loss: 0.0112
# Epoch [1/5], Step [1700], Loss: 0.1480
# Epoch [1/5], Step [1800], Loss: 0.0015
# Epoch [1/5], Step [1900], Loss: 0.0506
# Epoch [1/5], Step [2000], Loss: 0.2524
# Epoch [1/5], Step [2100], Loss: 0.0287
# Epoch [1/5], Step [2200], Loss: 0.2073
# Epoch [1/5], Step [2300], Loss: 0.1062
# Epoch [1/5], Step [2400], Loss: 0.0199
# Epoch [1/5], Step [2500], Loss: 0.0924
# Epoch [1/5], Step [2600], Loss: 0.3310
# Epoch [1/5], Step [2700], Loss: 0.0090
# Epoch [1/5], Step [2800], Loss: 0.0363
# Epoch [1/5], Step [2900], Loss: 0.0029
# Epoch [1/5], Step [3000], Loss: 0.0636
# Epoch [1/5], Step [3100], Loss: 0.0893
# Epoch [1/5], Step [3200], Loss: 0.1822
# Epoch [1/5], Step [3300], Loss: 0.0328
# Epoch [1/5], Step [3400], Loss: 0.0087
# Epoch [1/5], Step [3500], Loss: 0.1433
# Epoch [1/5], Step [3600], Loss: 0.0183
# Epoch [1/5], Step [3700], Loss: 0.0320
# Epoch [2/5], Step [100], Loss: 0.0089
# Epoch [2/5], Step [200], Loss: 0.0035
# Epoch [2/5], Step [300], Loss: 0.0021
# Epoch [2/5], Step [400], Loss: 0.2442
# Epoch [2/5], Step [500], Loss: 0.1341
# Epoch [2/5], Step [600], Loss: 0.0917
# Epoch [2/5], Step [700], Loss: 0.0001
# Epoch [2/5], Step [800], Loss: 0.0554
# Epoch [2/5], Step [900], Loss: 0.0376
# Epoch [2/5], Step [1000], Loss: 0.0000
# Epoch [2/5], Step [1100], Loss: 0.5154
# Epoch [2/5], Step [1200], Loss: 0.0901
# Epoch [2/5], Step [1300], Loss: 0.0041
# Epoch [2/5], Step [1400], Loss: 0.3471
# Epoch [2/5], Step [1500], Loss: 0.0100
# Epoch [2/5], Step [1600], Loss: 0.0148
# Epoch [2/5], Step [1700], Loss: 0.2467
# Epoch [2/5], Step [1800], Loss: 0.0287
# Epoch [2/5], Step [1900], Loss: 0.1542
# Epoch [2/5], Step [2000], Loss: 0.4304
# Epoch [2/5], Step [2100], Loss: 0.0734
# Epoch [2/5], Step [2200], Loss: 0.0596
# Epoch [2/5], Step [2300], Loss: 0.1030
# Epoch [2/5], Step [2400], Loss: 0.1106
# Epoch [2/5], Step [2500], Loss: 0.0065
# Epoch [2/5], Step [2600], Loss: 0.0502
# Epoch [2/5], Step [2700], Loss: 0.0426
# Epoch [2/5], Step [2800], Loss: 0.0086
# Epoch [2/5], Step [2900], Loss: 0.0484
# Epoch [2/5], Step [3000], Loss: 0.1664
# Epoch [2/5], Step [3100], Loss: 0.0284
# Epoch [2/5], Step [3200], Loss: 0.0492
# Epoch [2/5], Step [3300], Loss: 0.3995
# Epoch [2/5], Step [3400], Loss: 0.0569
# Epoch [2/5], Step [3500], Loss: 0.0012
# Epoch [2/5], Step [3600], Loss: 0.0106
# Epoch [2/5], Step [3700], Loss: 0.0009
# Epoch [3/5], Step [100], Loss: 0.0001
# Epoch [3/5], Step [200], Loss: 0.5730
# Epoch [3/5], Step [300], Loss: 0.0032
# Epoch [3/5], Step [400], Loss: 0.0146
# Epoch [3/5], Step [500], Loss: 0.0006
# Epoch [3/5], Step [600], Loss: 0.0156
# Epoch [3/5], Step [700], Loss: 0.0201
# Epoch [3/5], Step [800], Loss: 0.0616
# Epoch [3/5], Step [900], Loss: 0.0063
# Epoch [3/5], Step [1000], Loss: 0.6860
# Epoch [3/5], Step [1100], Loss: 0.0594
# Epoch [3/5], Step [1200], Loss: 0.0077
# Epoch [3/5], Step [1300], Loss: 0.1393
# Epoch [3/5], Step [1400], Loss: 0.0605
# Epoch [3/5], Step [1500], Loss: 0.1133
# Epoch [3/5], Step [1600], Loss: 0.0416
# Epoch [3/5], Step [1700], Loss: 0.0021
# Epoch [3/5], Step [1800], Loss: 0.0983
# Epoch [3/5], Step [1900], Loss: 0.0027
# Epoch [3/5], Step [2000], Loss: 0.0010
# Epoch [3/5], Step [2100], Loss: 0.0005
# Epoch [3/5], Step [2200], Loss: 0.6196
# Epoch [3/5], Step [2300], Loss: 0.0378
# Epoch [3/5], Step [2400], Loss: 0.0249
# Epoch [3/5], Step [2500], Loss: 0.1763
# Epoch [3/5], Step [2600], Loss: 0.0170
# Epoch [3/5], Step [2700], Loss: 0.0191
# Epoch [3/5], Step [2800], Loss: 0.0059
# Epoch [3/5], Step [2900], Loss: 0.0711
# Epoch [3/5], Step [3000], Loss: 0.0064
# Epoch [3/5], Step [3100], Loss: 0.1882
# Epoch [3/5], Step [3200], Loss: 0.0542
# Epoch [3/5], Step [3300], Loss: 0.0005
# Epoch [3/5], Step [3400], Loss: 0.0006
# Epoch [3/5], Step [3500], Loss: 0.2330
# Epoch [3/5], Step [3600], Loss: 0.0031
# Epoch [3/5], Step [3700], Loss: 0.0105
# Epoch [4/5], Step [100], Loss: 0.2524
# Epoch [4/5], Step [200], Loss: 0.0057
# Epoch [4/5], Step [300], Loss: 0.0894
# Epoch [4/5], Step [400], Loss: 0.0418
# Epoch [4/5], Step [500], Loss: 0.0116
# Epoch [4/5], Step [600], Loss: 0.0011
# Epoch [4/5], Step [700], Loss: 0.0034
# Epoch [4/5], Step [800], Loss: 0.0094
# Epoch [4/5], Step [900], Loss: 0.0159
# Epoch [4/5], Step [1000], Loss: 0.0859
# Epoch [4/5], Step [1100], Loss: 0.0311
# Epoch [4/5], Step [1200], Loss: 0.0079
# Epoch [4/5], Step [1300], Loss: 0.0158
# Epoch [4/5], Step [1400], Loss: 0.0042
# Epoch [4/5], Step [1500], Loss: 0.0564
# Epoch [4/5], Step [1600], Loss: 0.0176
# Epoch [4/5], Step [1700], Loss: 0.0482
# Epoch [4/5], Step [1800], Loss: 0.0005
# Epoch [4/5], Step [1900], Loss: 0.0028
# Epoch [4/5], Step [2000], Loss: 0.0579
# Epoch [4/5], Step [2100], Loss: 0.0000
# Epoch [4/5], Step [2200], Loss: 0.0245
# Epoch [4/5], Step [2300], Loss: 0.0149
# Epoch [4/5], Step [2400], Loss: 0.0000
# Epoch [4/5], Step [2500], Loss: 0.0864
# Epoch [4/5], Step [2600], Loss: 1.2413
# Epoch [4/5], Step [2700], Loss: 0.0988
# Epoch [4/5], Step [2800], Loss: 0.0277
# Epoch [4/5], Step [2900], Loss: 0.0013
# Epoch [4/5], Step [3000], Loss: 0.0660
# Epoch [4/5], Step [3100], Loss: 0.2436
# Epoch [4/5], Step [3200], Loss: 0.0288
# Epoch [4/5], Step [3300], Loss: 0.1221
# Epoch [4/5], Step [3400], Loss: 0.3380
# Epoch [4/5], Step [3500], Loss: 0.0003
# Epoch [4/5], Step [3600], Loss: 1.8160
# Epoch [4/5], Step [3700], Loss: 0.5262
# Epoch [5/5], Step [100], Loss: 0.3650
# Epoch [5/5], Step [200], Loss: 0.0098
# Epoch [5/5], Step [300], Loss: 0.1491
# Epoch [5/5], Step [400], Loss: 0.0175
# Epoch [5/5], Step [500], Loss: 0.0161
# Epoch [5/5], Step [600], Loss: 0.0007
# Epoch [5/5], Step [700], Loss: 0.2519
# Epoch [5/5], Step [800], Loss: 0.0003
# Epoch [5/5], Step [900], Loss: 0.0074
# Epoch [5/5], Step [1000], Loss: 0.1658
# Epoch [5/5], Step [1100], Loss: 0.1384
# Epoch [5/5], Step [1200], Loss: 0.0147
# Epoch [5/5], Step [1300], Loss: 0.0000
# Epoch [5/5], Step [1400], Loss: 0.0315
# Epoch [5/5], Step [1500], Loss: 0.0025
# Epoch [5/5], Step [1600], Loss: 0.3514
# Epoch [5/5], Step [1700], Loss: 0.0050
# Epoch [5/5], Step [1800], Loss: 0.0000
# Epoch [5/5], Step [1900], Loss: 0.0411
# Epoch [5/5], Step [2000], Loss: 0.0008
# Epoch [5/5], Step [2100], Loss: 0.0171
# Epoch [5/5], Step [2200], Loss: 0.0004
# Epoch [5/5], Step [2300], Loss: 0.0959
# Epoch [5/5], Step [2400], Loss: 0.0131
# Epoch [5/5], Step [2500], Loss: 0.0097
# Epoch [5/5], Step [2600], Loss: 0.0635
# Epoch [5/5], Step [2700], Loss: 0.6098
# Epoch [5/5], Step [2800], Loss: 0.0026
# Epoch [5/5], Step [2900], Loss: 0.0057
# Epoch [5/5], Step [3000], Loss: 0.0012
# Epoch [5/5], Step [3100], Loss: 0.0905
# Epoch [5/5], Step [3200], Loss: 0.4703
# Epoch [5/5], Step [3300], Loss: 0.0230
# Epoch [5/5], Step [3400], Loss: 0.0362
# Epoch [5/5], Step [3500], Loss: 0.0042
# Epoch [5/5], Step [3600], Loss: 0.1550
# Epoch [5/5], Step [3700], Loss: 0.0000

# %% [markdown]
# #### Test

# %%
cnn.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in dataloader_test:
        test_output, last_layer = cnn(images)
        pred_y = torch.max(test_output, 1)[1].data.squeeze()
        correct += (pred_y == labels).sum().item()
        total += labels.size(0)
    accuracy = correct / total * 100
    
print('Test Accuracy of the model on the 10000 test images: %.2f Percent' % accuracy)
# Out:
# Test Accuracy of the model on the 10000 test images: 97.13 Percent
