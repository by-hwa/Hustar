# %% [markdown]
# ## 03_Regression_v1_ipynb.pptx의 22p
# overfitting plotting code

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 10 data points
n = 10
x = np.linspace(-4.5, 4.5, 10).reshape(-1, 1)
y = np.array([0.9819, 0.7973, 1.9737, 0.1838, 1.3180, -0.8361, -0.6591, -2.4701, -2.8122, -6.2512]).reshape(-1, 1)

# %%
A=np.hstack([x**i for i in range(10)])  ### 달라지는 부분!!!  A정의
A=np.asmatrix(A)

theta = (A.T*A).I*A.T*y

# %%
xp = np.linspace(np.min(x), np.max(x))

### 달라지는 부분!! yp 구하는 부분! 
# 3차원 까지는 아래와 주석 같이 하나하나 써도 괜찮지만(18p처럼), 10차원이니 아래 코드와 같이 for문을 쓰면 더 간단하게 할 수 있음
# yp = theta[0,0] + theta[1,0]*xp + theta[2,0]*xp**2


yp = 0
for i in range(10):
  yp +=theta[i,0]*xp**i

# %%
plt.figure(figsize = (10, 8))
plt.plot(x, y, 'o', markersize = 4, label = 'actual')
plt.plot(xp, yp, 'r', linewidth = 2, label = 'estimated')

plt.title('Nonlinear regression', fontsize = 15)
plt.xlabel('X', fontsize = 15)
plt.ylabel('Y', fontsize = 15)
plt.xlim([np.min(x), np.max(x)])
plt.grid(alpha = 0.3)
plt.legend(fontsize = 15)
plt.show()
